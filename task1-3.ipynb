# %%
# !pip show ehrapy
# Out:
# Name: ehrapy
# Version: 0.10.0
# Summary: Electronic Health Record Analysis with Python.
# Home-page:
# Author: Lukas Heumos, Philipp Ehmele, Eljas Roellin, Lilly May, Tim Treis, Altana Namsaraeva, Vladimir Shitov, Luke Zappia, Xinyue Zhang
# Author-email:
# License: Apache License
#                            Version 2.0, January 2004
#                         http://www.apache.org/licenses/
#
#    TERMS AND CONDITIONS FOR USE, REPRODUCTION, AND DISTRIBUTION
#
#    1. Definitions.
#
#       "License" shall mean the terms and conditions for use, reproduction,
#       and distribution as defined by Sections 1 through 9 of this document.
#
#       "Licensor" shall mean the copyright owner or entity authorized by
#       the copyright owner that is granting the License.
#
#       "Legal Entity" shall mean the union of the acting entity and all
#       other entities that control, are controlled by, or are under common
# ...

# %%
try:
    import ehrapy
    print("Ehrapy is installed!")
except ImportError as e:
    print(f"Ehrapy is not installed: {e}")
# Out:
# Ehrapy is installed!

# %%
import sys
print(sys.executable)
# Out:
# /home/rin_kunisada/ehrapy_env/bin/python

# %%
import sys
print("\n".join(sys.path))
# Out:
# /usr/lib/python312.zip
# /usr/lib/python3.12
# /usr/lib/python3.12/lib-dynload
#
# /home/rin_kunisada/ehrapy_env/lib/python3.12/site-packages

# %%
import pandas as pd

# %%
csv_file_path = "data-CAT.csv"  
input_data = pd.read_csv(csv_file_path)

# %%
print(input_data.head())
# Out:
#          Field                                          sample_ID  \
# 0  Description  Identification number of the sample. This is t...
# 1       Values                                                NaN
# 2     Examples                                   SC24; SC25; SC28
# 3          NaN                                                NaN
# 4          NaN                                             PDAC14
#
#                                          ID_scRNAseq NIssc Status_OS   OS  \
# 0  This must be free-text that identifies a uniqu...   NaN       NaN  NaN
# 1  It is strongly recommended that this identifie...   NaN       NaN  NaN
# 2                 CR_donor_1; MM_donor_1; LR_donor_2   NaN       NaN  NaN
# 3                FILL OUT INFORMATION BELOW THIS ROW   NaN       NaN  NaN
# 4                                                746     2       NaN  NaN
#
#                                    PFS_sum Status_PFS  PFS Liver_met_sum  ...  \
# ...

# %%
column_types = {
    "ordinal": [
        "pT_status", "pN_status", "G_status", "L_status", "V_status", "Pn_status", "R_status", "M_status_postop"
    ],
    "nominal": [
        "sample_ID", "sex", "Localisation", "OP_technique", "histology", "Clavien-Dindo"
    ],
    "numerical": [
        "age_at_diagnosis", "Size_cm", "Weight_kg", "BMI", "Tumorsize_mm", "Number_resected_lymphnodes", 
        "Number_tumor_infiltrated_lymphnodes", "Ratio_tumorLN/resectedLN"
    ]
}

# %%
adata = Ehrapy.read_csv(
    file=csv_file_path,
    delimiter=",",
    column_types=column_types
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 adata = Ehrapy.read_csv(
#       2     file=csv_file_path,
#       3     delimiter=",",
#       4     column_types=column_types
#       5 )
#
# NameError: name 'Ehrapy' is not defined
